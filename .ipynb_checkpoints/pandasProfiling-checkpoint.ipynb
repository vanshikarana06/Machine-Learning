# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Step 1: Load the dataset
file_path = r"C:\Users\sus\OneDrive\Documents\customers.csv"
df = pd.read_csv(file_path)

# Step 2: Create the profiling report
profile = ProfileReport(df, title="Customer Dataset Report", explorative=True)

# Step 3: Export the report as an HTML file
profile.to_file("customer_report.html")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
