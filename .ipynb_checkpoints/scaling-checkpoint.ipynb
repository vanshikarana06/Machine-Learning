# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\sus\train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
x= df.drop("Embarked", axis=1)
y = df["Embarked"]

# %%
x
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Age"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 714 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB

# %%
df["Age"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 714 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB

# %%
df = df.dropna(subset=['Age'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male -0.115385
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.192308
# 2                               Heikkinen, Miss. Laina  female -0.038462
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.134615
# 4                             Allen, Mr. William Henry    male  0.134615
# ..                                                 ...     ...       ...
# ...

# %%
#splitting the data
from sklearn.model_selection import train_test_split
xtrain, ytest, ytrain , ytest = train_test_split(x, y , random_state= 42 , test_size=0.2)

# %%
# standarizing the Age column
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_age_scaled= scaler.fit_transform(df[["Age"]])

# %%
df_age_scaled
# Out:
# array([[-0.53037664],
#        [ 0.57183099],
#        [-0.25482473],
#        [ 0.36516706],
#        [ 0.36516706],
#        [ 1.67403863],
#        [-1.90813618],
#        [-0.18593675],
#        [-1.08148046],
#        [-1.77036023],
#        [ 1.94959054],
#        [-0.6681526 ],
#        [ 0.64071897],
#        [-1.08148046],
#        [ 1.74292661],
#        [-1.90813618],
#        [ 0.08961515],
#        [ 0.36516706],
#        [ 0.29627909],
#        [-1.01259248],
#        [-0.11704878],
#        [-1.49480832],
#        [ 0.57183099],
#        [-0.73704057],
#        [ 0.70960695],
#        [ 2.50069435],
#        [-0.11704878],
#        [ 0.8473829 ],
#        [-0.59926462],
#        [-0.80592855],
#        [-1.08148046],
#        [ 0.70960695],
#        [-0.18593675],
#        [-1.83924821],
#        [-0.73704057],
#        [-0.80592855],
#        [-1.5636963 ],
#        [-0.59926462],
#        [ 1.32959874],
#        [-0.0481608 ],
#        [ 2.43180638],
# ...

# %%
# min max scaling
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
df_scaled2 = scaler.fit_transform(df[["Age"]])

# %%
df_scaled2
# Out:
# array([[0.27117366],
#        [0.4722292 ],
#        [0.32143755],
#        [0.43453129],
#        [0.43453129],
#        [0.67328474],
#        [0.01985423],
#        [0.33400352],
#        [0.17064589],
#        [0.04498618],
#        [0.72354863],
#        [0.24604172],
#        [0.48479517],
#        [0.17064589],
#        [0.68585072],
#        [0.01985423],
#        [0.3842674 ],
#        [0.43453129],
#        [0.42196532],
#        [0.18321186],
#        [0.34656949],
#        [0.09525006],
#        [0.4722292 ],
#        [0.23347575],
#        [0.49736115],
#        [0.8240764 ],
#        [0.34656949],
#        [0.52249309],
#        [0.25860769],
#        [0.22090978],
#        [0.17064589],
#        [0.49736115],
#        [0.33400352],
#        [0.03242021],
#        [0.23347575],
#        [0.22090978],
#        [0.08268409],
#        [0.25860769],
#        [0.61045489],
#        [0.35913546],
#        [0.81151043],
#        [0.25860769],
#        [0.35285248],
# ...

# %%
#Mean Absolute Scaling (also known as robust scaling)
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
df_scaled3 = scaler.fit_transform(df[['Age']])

# %%
df_scaled3
# Out:
# array([[-0.33566434],
#        [ 0.55944056],
#        [-0.11188811],
#        [ 0.39160839],
#        [ 0.39160839],
#        [ 1.45454545],
#        [-1.45454545],
#        [-0.05594406],
#        [-0.78321678],
#        [-1.34265734],
#        [ 1.67832168],
#        [-0.44755245],
#        [ 0.61538462],
#        [-0.78321678],
#        [ 1.51048951],
#        [-1.45454545],
#        [ 0.16783217],
#        [ 0.39160839],
#        [ 0.33566434],
#        [-0.72727273],
#        [ 0.        ],
#        [-1.11888112],
#        [ 0.55944056],
#        [-0.5034965 ],
#        [ 0.67132867],
#        [ 2.12587413],
#        [ 0.        ],
#        [ 0.78321678],
#        [-0.39160839],
#        [-0.55944056],
#        [-0.78321678],
#        [ 0.67132867],
#        [-0.05594406],
#        [-1.3986014 ],
#        [-0.5034965 ],
#        [-0.55944056],
#        [-1.17482517],
#        [-0.39160839],
#        [ 1.17482517],
#        [ 0.05594406],
#        [ 2.06993007],
# ...

# %%
# max absolte scaling
from sklearn.preprocessing import MaxAbsScaler

scaler = MaxAbsScaler()
df_scaled4 = scaler.fit_transform(df[['Age']])

# %%
df_scaled4
# Out:
# array([[-0.11538462],
#        [ 0.19230769],
#        [-0.03846154],
#        [ 0.13461538],
#        [ 0.13461538],
#        [ 0.5       ],
#        [-0.5       ],
#        [-0.01923077],
#        [-0.26923077],
#        [-0.46153846],
#        [ 0.57692308],
#        [-0.15384615],
#        [ 0.21153846],
#        [-0.26923077],
#        [ 0.51923077],
#        [-0.5       ],
#        [ 0.05769231],
#        [ 0.13461538],
#        [ 0.11538462],
#        [-0.25      ],
#        [ 0.        ],
#        [-0.38461538],
#        [ 0.19230769],
#        [-0.17307692],
#        [ 0.23076923],
#        [ 0.73076923],
#        [ 0.        ],
#        [ 0.26923077],
#        [-0.13461538],
#        [-0.19230769],
#        [-0.26923077],
#        [ 0.23076923],
#        [-0.01923077],
#        [-0.48076923],
#        [-0.17307692],
#        [-0.19230769],
#        [-0.40384615],
#        [-0.13461538],
#        [ 0.40384615],
#        [ 0.01923077],
#        [ 0.71153846],
# ...

# %%
import seaborn as sns
sns.kdeplot(df_scaled4)
# Out:
# <Axes: ylabel='Density'>
