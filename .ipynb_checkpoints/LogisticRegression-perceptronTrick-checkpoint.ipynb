# %% [markdown]
# # Perceptron learning

# %%
from sklearn.datasets import make_classification
import numpy as np
x,y = make_classification(n_samples=100, n_features=2, n_informative=1 , n_redundant=0 , n_classes=2 ,  n_clusters_per_class=1 , random_state=42 , hypercube=False , class_sep=10)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.scatter(x[:,0],x[:,1], c=y, cmap="winter", s=100)
plt.show()

# %%
# def perceptron(X,y):
    
#     X = np.insert(X,0,1,axis=1)
#     weights = np.ones(X.shape[1])
#     lr = 0.1
    
#     # for i in range(1000):
#     #     j = np.random.randint(0,100)
#     #     y_hat = step(np.dot(X[j],weights))
#     #     weights = weights + lr*(y[j]-y_hat)*X[j]
        
    
#     for i in range(1000):
#      for j in range(len(X)):
#         y_hat = step(np.dot(X[j],weights))
#         weights = weights + lr*(y[j]-y_hat)*X[j]
#     return weights[0],weights[1:]
def perceptron(X, y):
    X = np.insert(X, 0, 1, axis=1)   # add bias column
    weights = np.ones(X.shape[1])
    lr = 0.1
    
    for i in range(1000):
        j = np.random.randint(0, 100)
        y_hat = step(np.dot(X[j], weights))
        weights = weights + lr * (y[j] - y_hat) * X[j]
    
    b = weights[0]
    w1 = weights[1]
    w2 = weights[2]
    
    return b, w1, w2

# %%
def step(z):
    return 1 if z>0 else 0

# %%
intercept_ , coef1 , coef2 = perceptron(x,y)

# %%
print(coef_)
# Out:
# [0.93794518 1.16135105]

# %%
print(intercept_)
# Out:
# 0.9

# %%
m= -(coef_[0]/coef_[1])
b=-(intercept_/coef_[1])

# %%
x_input= np.linspace(-3,3,100)
y_input=m*x_input+b

# %%
x_input
# Out:
# array([-3.        , -2.93939394, -2.87878788, -2.81818182, -2.75757576,
#        -2.6969697 , -2.63636364, -2.57575758, -2.51515152, -2.45454545,
#        -2.39393939, -2.33333333, -2.27272727, -2.21212121, -2.15151515,
#        -2.09090909, -2.03030303, -1.96969697, -1.90909091, -1.84848485,
#        -1.78787879, -1.72727273, -1.66666667, -1.60606061, -1.54545455,
#        -1.48484848, -1.42424242, -1.36363636, -1.3030303 , -1.24242424,
#        -1.18181818, -1.12121212, -1.06060606, -1.        , -0.93939394,
#        -0.87878788, -0.81818182, -0.75757576, -0.6969697 , -0.63636364,
#        -0.57575758, -0.51515152, -0.45454545, -0.39393939, -0.33333333,
#        -0.27272727, -0.21212121, -0.15151515, -0.09090909, -0.03030303,
#         0.03030303,  0.09090909,  0.15151515,  0.21212121,  0.27272727,
#         0.33333333,  0.39393939,  0.45454545,  0.51515152,  0.57575758,
#         0.63636364,  0.6969697 ,  0.75757576,  0.81818182,  0.87878788,
#         0.93939394,  1.        ,  1.06060606,  1.12121212,  1.18181818,
#         1.24242424,  1.3030303 ,  1.36363636,  1.42424242,  1.48484848,
#         1.54545455,  1.60606061,  1.66666667,  1.72727273,  1.78787879,
#         1.84848485,  1.90909091,  1.96969697,  2.03030303,  2.09090909,
#         2.15151515,  2.21212121,  2.27272727,  2.33333333,  2.39393939,
#         2.45454545,  2.51515152,  2.57575758,  2.63636364,  2.6969697 ,
#         2.75757576,  2.81818182,  2.87878788,  2.93939394,  3.        ])

# %%
y_input
# Out:
# array([ 1.64793886,  1.59899142,  1.55004398,  1.50109654,  1.4521491 ,
#         1.40320166,  1.35425422,  1.30530678,  1.25635933,  1.20741189,
#         1.15846445,  1.10951701,  1.06056957,  1.01162213,  0.96267469,
#         0.91372725,  0.86477981,  0.81583236,  0.76688492,  0.71793748,
#         0.66899004,  0.6200426 ,  0.57109516,  0.52214772,  0.47320028,
#         0.42425284,  0.37530539,  0.32635795,  0.27741051,  0.22846307,
#         0.17951563,  0.13056819,  0.08162075,  0.03267331, -0.01627414,
#        -0.06522158, -0.11416902, -0.16311646, -0.2120639 , -0.26101134,
#        -0.30995878, -0.35890622, -0.40785366, -0.45680111, -0.50574855,
#        -0.55469599, -0.60364343, -0.65259087, -0.70153831, -0.75048575,
#        -0.79943319, -0.84838063, -0.89732808, -0.94627552, -0.99522296,
#        -1.0441704 , -1.09311784, -1.14206528, -1.19101272, -1.23996016,
#        -1.2889076 , -1.33785505, -1.38680249, -1.43574993, -1.48469737,
#        -1.53364481, -1.58259225, -1.63153969, -1.68048713, -1.72943457,
#        -1.77838202, -1.82732946, -1.8762769 , -1.92522434, -1.97417178,
#        -2.02311922, -2.07206666, -2.1210141 , -2.16996154, -2.21890899,
#        -2.26785643, -2.31680387, -2.36575131, -2.41469875, -2.46364619,
#        -2.51259363, -2.56154107, -2.61048851, -2.65943596, -2.7083834 ,
#        -2.75733084, -2.80627828, -2.85522572, -2.90417316, -2.9531206 ,
#        -3.00206804, -3.05101548, -3.09996293, -3.14891037, -3.19785781])

# %%
# plt.figure(figsize=(15,10))
# plt.plot(x_input, y_input  , color="red", linewidth=3)
# plt.scatter(x[:,0], x[:,1], c=y, cmap='winter', s=100)
# plt.ylim(-3,2)
# plt.show()

plt.figure(figsize=(10,6))
plt.scatter(x[:,0], x[:,1], c=y, cmap='winter', s=100)
plt.plot(x_input, y_input, color='red', linewidth=3)

plt.ylim(-3,2)
plt.show()

# %%
# b, w = perceptron(x, y)

# plt.figure(figsize=(10,6))
# plt.scatter(x[:,0], x[:,1], c=y, cmap='winter', s=100)

# x_vals = np.linspace(x[:,0].min(), x[:,0].max(), 100)
# y_vals = -(w[0]*x_vals + b)/w[1]   # equation: w1*x + w2*y + b = 0
# plt.plot(x_vals, y_vals, color='red', linewidth=3)

# plt.ylim(-3,2)
# plt.show()
b, w = perceptron(x, y)   # get bias and weight array
w1, w2 = w                # unpack weights

plt.figure(figsize=(10,6))
plt.scatter(x[:,0], x[:,1], c=y, cmap='winter', s=100)

x_vals = np.linspace(x[:,0].min(), x[:,0].max(), 100)
y_vals = -(w1*x_vals + b)/w2
plt.plot(x_vals, y_vals, color='red', linewidth=3)

plt.ylim(-3,2)
plt.show()
# Out:
# ----------------------------------------------------------------
# ValueError                     Traceback (most recent call last)
# Cell In[86], line 12
#       1 # b, w = perceptron(x, y)
#       2
#       3 # plt.figure(figsize=(10,6))
#    (...)
#      10 # plt.ylim(-3,2)
#      11 # plt.show()
# ---> 12 b, w = perceptron(x, y)   # get bias and weight array
#      13 w1, w2 = w                # unpack weights
#      15 plt.figure(figsize=(10,6))
#
# ValueError: too many values to unpack (expected 2)

# %%
def perceptron(X,y):
    
    m = []
    b = []
    
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.1
    
    for i in range(200):
        j = np.random.randint(0,100)
        y_hat = step(np.dot(X[j],weights))
        weights = weights + lr*(y[j]-y_hat)*X[j]
        
        m.append(-(weights[1]/weights[2]))
        b.append(-(weights[0]/weights[2]))
        
    return m,b

# %%
m,b = perceptron(x,y)

# %%
# !pip install ipympl
# Out:
# Requirement already satisfied: ipympl in c:\users\sus\anaconda3\lib\site-packages (0.9.7)
# Requirement already satisfied: ipython<10 in c:\users\sus\anaconda3\lib\site-packages (from ipympl) (8.27.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\sus\anaconda3\lib\site-packages (from ipympl) (7.8.1)
# Requirement already satisfied: matplotlib<4,>=3.5.0 in c:\users\sus\anaconda3\lib\site-packages (from ipympl) (3.9.2)
# Requirement already satisfied: numpy in c:\users\sus\anaconda3\lib\site-packages (from ipympl) (1.26.4)
# Requirement already satisfied: pillow in c:\users\sus\anaconda3\lib\site-packages (from ipympl) (10.4.0)
# Requirement already satisfied: traitlets<6 in c:\users\sus\anaconda3\lib\site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: decorator in c:\users\sus\anaconda3\lib\site-packages (from ipython<10->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sus\anaconda3\lib\site-packages (from ipython<10->ipympl) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\sus\anaconda3\lib\site-packages (from ipython<10->ipympl) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\sus\anaconda3\lib\site-packages (from ipython<10->ipympl) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sus\anaconda3\lib\site-packages (from ipython<10->ipympl) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\sus\anaconda3\lib\site-packages (from ipython<10->ipympl) (0.2.0)
# Requirement already satisfied: colorama in c:\users\sus\anaconda3\lib\site-packages (from ipython<10->ipympl) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\sus\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\sus\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\sus\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\sus\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sus\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sus\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sus\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sus\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sus\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sus\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sus\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\sus\anaconda3\lib\site-packages (from jedi>=0.16->ipython<10->ipympl) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\sus\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<10->ipympl) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\sus\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.5.0->ipympl) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\sus\anaconda3\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (7.2.2)
# Requirement already satisfied: executing in c:\users\sus\anaconda3\lib\site-packages (from stack-data->ipython<10->ipympl) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\sus\anaconda3\lib\site-packages (from stack-data->ipython<10->ipympl) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\sus\anaconda3\lib\site-packages (from stack-data->ipython<10->ipympl) (0.2.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\sus\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\sus\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\sus\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\sus\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\sus\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (6.4.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\sus\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\sus\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\sus\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\sus\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (2.2.0)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\sus\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (75.1.0)
# Requirement already satisfied: babel>=2.10 in c:\users\sus\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\sus\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\sus\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\sus\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\sus\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sus\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\sus\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\sus\anaconda3\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (2024.1)
# Requirement already satisfied: certifi in c:\users\sus\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\sus\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sus\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\sus\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (1.6.7)
# Requirement already satisfied: nest-asyncio in c:\users\sus\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (1.6.0)
# Requirement already satisfied: psutil in c:\users\sus\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (5.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sus\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sus\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sus\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sus\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sus\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (305.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\sus\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\sus\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\sus\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\sus\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\sus\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\sus\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\sus\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\sus\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\sus\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\sus\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (1.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\sus\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sus\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sus\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (2.2.3)
# Requirement already satisfied: webencodings in c:\users\sus\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\sus\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\sus\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\sus\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (2.1)
# Requirement already satisfied: uri-template in c:\users\sus\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\sus\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\sus\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sus\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (2.5)
# Requirement already satisfied: pycparser in c:\users\sus\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\sus\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipympl) (1.2.3)

# %%
# %matplotlib widget
# %matplotlib inline
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

# %%
fig, ax = plt.subplots(figsize=(9,5))

x_i = np.arange(-3, 3, 0.1)
y_i = x_i*m[0] +b[0]
ax.scatter(x[:,0],x[:,1],c=y,cmap='winter',s=100)
line, = ax.plot(x_i, x_i*m[0] +b[0] , 'r-', linewidth=2)
plt.ylim(-3,3)
def update(i):
    label = 'epoch {0}'.format(i + 1)
    line.set_ydata(x_i*m[i] + b[i])
    ax.set_xlabel(label)
    # return line, ax

anim = FuncAnimation(fig, update, repeat=True, frames=200, interval=100)
