# %%
from  sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
x, y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20)

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [63.81432526]
# -0.41487760055500883

# %%
m=29.19

# %%
class GDRegressor: 
    def __init__(self, learning_rate, epochs):  
        self.m=29.19
        self.b=-120
        self.lr=learning_rate
        self.epochs=epochs
    def fit(self,x,y):
        for i in range(self.epochs):
            loss_slope=-2*np.sum(y-self.m*x.ravel()-self.b)
            self.b=self.b-(self.lr*loss_slope)
            print(loss_slope,self.b)
        print(self.b)

# %%
gd=GDRegressor(0.1,10)
gd.fit(x,y)
# Out:
# -23995.958451547656 2279.595845154766
# 455923.2105794056 -43312.7252127858
# -8662541.001008708 822941.3748880851
# 164588279.0191655 -15635886.527028464
# -3127177301.364145 297081843.609386
# 59416368725.91875 -5644555028.982489
# -1128911005792.456 107246545550.26312
# 21449309110056.668 -2037684365455.4038
# -407536873091076.7 38716002943652.266
# 7743200588730458.0 -735604055929393.6
# -735604055929393.6
