# %%
from sklearn.preprocessing import OrdinalEncoder
oe= OrdinalEncoder()

# %%
import pandas as pd
df= pd.read_csv(r"C:\Users\sus\train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df= df.dropna(subset=["Cabin"])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# ordinal encoding on cabin column
# but technicallly we should not apply oe to it , as there is no order for the cabin
# cabin_encoded= oe.fit_transform(df[["Cabin"]])

# %%
cabin_encoded
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 cabin_encoded
#
# NameError: name 'cabin_encoded' is not defined

# %%
# one hot encoding 
# a= pd.get_dummies(df, columns=['Cabin'])

# %%
a

# %%
# using sklearn
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder(drop="first", sparse_output=True)
cabin_encoded2 = ohe.fit_transform(df[["Cabin"]]).toarray()

# %%
cabin_encoded2

# %%
encoded_df = pd.DataFrame(cabin_encoded2, columns=ohe.get_feature_names_out(["Cabin"]))
df = df.drop("Cabin", axis=1).reset_index(drop=True)
df = pd.concat([df, encoded_df], axis=1)

# %%
df
