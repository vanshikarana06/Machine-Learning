# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
import pandas as pd

# Your original df is already loaded

# Define your transformer
transform = ColumnTransformer(transformers=[
    ('age_imputer', SimpleImputer(), ['Age']),
    ('sex_encoder', OneHotEncoder(drop='first'), ['Sex']),
    ('ticket_encoder', OrdinalEncoder(), ['Ticket'])
], remainder='passthrough')

# Fit and transform
transformed_data = transform.fit_transform(df)

# Get column names
column_names = transform.get_feature_names_out()

# Create new DataFrame with proper column names
new_df = pd.DataFrame(transformed_data, columns=column_names)

# Preview
print(new_df.head())
# Out:
#   age_imputer__Age sex_encoder__Sex_male ticket_encoder__Ticket  \
# 0             22.0                   1.0                  523.0
# 1             38.0                   0.0                  596.0
# 2             26.0                   0.0                  669.0
# 3             35.0                   0.0                   49.0
# 4             35.0                   1.0                  472.0
#
#   remainder__PassengerId remainder__Survived remainder__Pclass  \
# 0                      1                   0                 3
# 1                      2                   1                 1
# 2                      3                   1                 3
# 3                      4                   1                 1
# 4                      5                   0                 3
#
#                                      remainder__Name remainder__SibSp  \
# 0                            Braund, Mr. Owen Harris                1
# ...

# %%
new_df
# Out:
#     age_imputer__Age sex_encoder__Sex_male ticket_encoder__Ticket  \
# 0               22.0                   1.0                  523.0
# 1               38.0                   0.0                  596.0
# 2               26.0                   0.0                  669.0
# 3               35.0                   0.0                   49.0
# 4               35.0                   1.0                  472.0
# ..               ...                   ...                    ...
# 886             27.0                   1.0                  101.0
# 887             19.0                   0.0                   14.0
# 888        29.699118                   0.0                  675.0
# 889             26.0                   1.0                    8.0
# 890             32.0                   1.0                  466.0
#
#     remainder__PassengerId remainder__Survived remainder__Pclass  \
# 0                        1                   0                 3
# ...
